# %%
from src.utils import get_llm

prompt = "Write a code for binary search in python"

llm = get_llm()
response = llm.invoke(prompt).content

# %%
print(response)
# Out:
# **Binary Search Algorithm in Python**
# ...
#
# Binary search is an efficient algorithm for finding an item from a sorted list of items. It works by repeatedly dividing in half the portion of the list that could contain the item, until you've narrowed down the possible locations to just one.
#
# **Code**
# --------
#
# ```python
# def binary_search(arr, target):
#     """
#     Searches for the target element in the sorted array using binary search.
#
#     Args:
#         arr (list): A sorted list of elements.
#         target: The element to be searched.
#
#     Returns:
#         int: The index of the target element if found, -1 otherwise.
#     """
#     low = 0
#     high = len(arr) - 1
#
#     while low <= high:
#         mid = (low + high) // 2
#         if arr[mid] == target:
#             return mid
#         elif arr[mid] < target:
#             low = mid + 1
#         else:
#             high = mid - 1
#
#     return -1
#
# # Example usage:
# ...

# %%
from src.utils import fetch_data

results = fetch_data("Latest AAA titles in 2026", max_results=5)

# %%
for result in results:
    print(f"Title: {result['title']}")
    print(f"Link: {result['href']}")
    print(f"Snippet: {result['body']}\n")
# Out:
# Title: 2026in film - Wikipedia
# Link: https://en.wikipedia.org/wiki/2026_in_film
# Snippet: 2026in film is an overview of events in the film industry scheduled to occurin2026. Best Picture Academy Award-winner All Quiet on the Western Front entered the public domain this year.
#
# Title: The 10 BestAAAGames of 2025 and Upcoming Releasesin2026
# Link: https://fgfactory.com/best-10-aaa-games
# Snippet: Best 10AAAGames and Upcoming Releasesin2026. Have Questions? Take a minute, we’d love to hear about your request.In this article, we highlight the topAAAgames that were already released in 2025 and the most anticipated games that are expected to comein2026.
#
# Title: Top 16AAAGames You Must Playin2026
# Link: https://geekflare.com/gaming/top-aaa-games/
# Snippet: Explore the topAAAgames for an enjoyable day. Dive into epic adventures, stunning graphics, and immersive storytelling. Get ready to play!
#
# Title: Embracer Group Plans To Release Up To 19AAATitlesInThe Next...
# ...

# %%
from src.agents.research_agent import ResearchAgent

# Initialize the agent
agent = ResearchAgent()

# Run for a specific product
result = agent.run(
    product_title="AI Data Analysis Tool",
    product_description="An AI-based tool for exploring and visualizing datasets."
)

# %%
print(result["analysis"])
# Out:
# Based on the provided competitors for the product 'AI Data Analysis Tool', I will analyze each competitor and provide details on their name, pricing (if available), description, pros, and cons.
#
# ### 1. GoodData
#
# * **Name**: GoodData
# * **Pricing**: Not available in the provided data
# * **Description**: GoodData is a cloud-based data analytics platform that provides strong visualization and an AI assistant to accelerate analysis and authoring.
# * **Pros**: Strong visualization, AI assistant for accelerated analysis and authoring
# * **Cons**: Pricing information not available, may not be suitable for teams with complex data analysis needs
#
# ### 2. Tableau
#
# * **Name**: Tableau
# * **Pricing**: Not available in the provided data
# * **Description**: Tableau is a data visualization and business intelligence platform that enables users to create interactive and dynamic visualizations, handle complex and large datasets, and provide real-time analytics capabilities.
# ...
