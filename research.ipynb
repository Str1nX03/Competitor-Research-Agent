# %%
from src.utils import get_llm

prompt = "Write a code for binary search in python"

llm = get_llm()
response = llm.invoke(prompt).content

# %%
print(response)
# Out:
# **Binary Search Algorithm in Python**
# =====================================
#
# Binary search is an efficient algorithm for finding an item from a sorted list of items. It works by repeatedly dividing in half the portion of the list that could contain the item, until you've narrowed down the possible locations to just one.
#
# **Code**
# --------
#
# ```python
# def binary_search(arr, target):
#     """
#     Searches for the target element in the sorted array using binary search.
#
#     Args:
#         arr (list): A sorted list of elements.
#         target: The element to be searched.
#
#     Returns:
#         int: The index of the target element if found, -1 otherwise.
#     """
#     low = 0
#     high = len(arr) - 1
#
#     while low <= high:
#         mid = (low + high) // 2
#         if arr[mid] == target:
#             return mid
#         elif arr[mid] < target:
#             low = mid + 1
#         else:
#             high = mid - 1
#
#     return -1
#
# # Example usage:
# arr = [2, 5, 8, 12, 16, 23, 38, 56, 72, 91]
# target = 23
#
# result = binary_search(arr, target)
#
# if result != -1:
#     print(f"Element {target} found at index {result}.")
# else:
#     print(f"Element {target} not found in the array.")
# ```
#
# **Explanation**
# ---------------
#
# 1.  Initialize two pointers, `low` and `high`, to the start and end of the array, respectively.
# 2.  Calculate the middle index `mid` using the formula `(low + high) // 2`.
# 3.  Compare the middle element `arr[mid]` with the target element.
#     *   If they are equal, return the middle index `mid`.
#     *   If the middle element is less than the target, move the `low` pointer to `mid + 1`.
#     *   If the middle element is greater than the target, move the `high` pointer to `mid - 1`.
# 4.  Repeat steps 2-3 until `low` is greater than `high`.
# 5.  If the target element is not found, return -1.
#
# **Time Complexity**
# -------------------
#
# The time complexity of binary search is O(log n), where n is the number of elements in the array. This is because with each iteration, the search space is halved.

# %%
from src.utils import fetch_data

# Fetch the top 3 results for a query
results = fetch_data("Latest AAA titles in 2026", max_results=3)

for result in results:
    print(f"Title: {result['title']}")
    print(f"Link: {result['href']}")
    print(f"Snippet: {result['body']}\n")
# Out:
# Title: AAA Games - A Comprehensive Guide to the Best Titles in 2026
# Link: https://wikitechlibrary.com/aaa-games-a-comprehensive-guide/
# Snippet: AAAgamesin2026aren’t just about budgets — they’re about scale, polish, and ambition. ...AAAtitlesare becoming more than just games, ...
#
# Title: Top 10 AAA Games Releasing In 2026 | NoobFeed
# Link: https://www.noobfeed.com/articles/top-10-aaa-games-releasing-in-2026
# Snippet: ... suggests the third installment could emergein2026or later, offering fans another brutal excursion into the grim darkness of the far future.
#
# Title: Wait is Over: Here's Upcoming AAA game titles for PC 2025
# Link: https://funtecho.com/wait-is-over-heres-is-the-list-of-upcoming-aaa-game-titles-for-pc-try-in-2025/
# Snippet: ... s is the list of UpcomingAAAGameTitlesfor PC (Tryin... The increase of theseAAAtitlesin2025inPC game numbers is especially unprecedented.
